# %% [markdown]
# # Safety Category

# %%
import numpy as np
import pandas as pd

# %%
# Read the data
data_dictionary = pd.read_excel("safety/data_dictionary.xlsx")
features = pd.read_table("safety/features/part-00001-e6120af0-10c2-4248-97c4-81baf4304e5c-c000.csv", sep=r'\,|\t', engine='python')
labels = pd.read_table("safety/labels/labels.csv", sep=r'\,|\t', engine='python')

# %%
data_dictionary.head()
# Out:
#             bookingID                            Accuracy      Bearing  \
# description   trip id  accuracy inferred by GPS in meters  GPS bearing
# samples             1                                   5      303.695
# NaN                 1                                  10       325.39
# NaN                 1                                   5      303.695
# NaN                 1                                  10       324.23
#
#                                      acceleration_x  \
# description  accelerometer reading in x axis (m/s2)
# samples                                 -0.00636292
# NaN                                        0.183914
# NaN                                     -0.00636292
# NaN                                        0.165924
#
#                                      acceleration_y  \
# description  accelerometer reading in y axis (m/s2)
# samples                                   -0.393829
# NaN                                       -0.355026
# ...

# %%
features.head()
# Out:
#        bookingID  Accuracy     Bearing  acceleration_x  acceleration_y  \
# 0  1194000908341     4.000  203.000000        1.001973        9.745000
# 1  1099511627891     3.000  311.000000        0.452518        9.273026
# 2   962072674446    10.000  142.807999        0.018542       -8.041156
# 3  1142461300867     8.000  171.205292       -0.290698       -8.295367
# 4   412316860548    19.379    0.000000        0.675613        8.846130
#
#    acceleration_z    gyro_x    gyro_y    gyro_z  second      Speed
# 0       -0.790087 -0.066046  0.019175  0.044741   246.0   6.480000
# 1        3.098191  0.005382  0.002155 -0.001436    66.0   0.340365
# 2       -4.960114  0.004223 -0.014875  0.007397  1552.0   2.050000
# 3       -3.049042  0.033618  0.046224  0.030559   277.0  17.608448
# 4        1.852508 -0.008652  0.003693  0.001160   148.0   0.000000

# %%
labels.head()
# Out:
#        bookingID  label
# 0   111669149733      0
# 1   335007449205      1
# 2   171798691856      0
# 3  1520418422900      0
# 4   798863917116      0
